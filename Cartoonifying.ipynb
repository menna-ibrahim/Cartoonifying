# %% [markdown]
# <a href="https://colab.research.google.com/github/menna-ibrahim/Cartoonifying/blob/main/Cartoonifying.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sp
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
from scipy import signal
import math

# %%
guy_image = cv2.imread('guy.png')
road_image = cv2.imread('road.jpg')
print("guy image: dims:{} type{}:".format(guy_image.shape,type(guy_image)))
print("road image: dims:{} type{}:".format(road_image.shape,type(road_image)))
# Out:
# guy image: dims:(397, 263, 3) type<class 'numpy.ndarray'>:
# road image: dims:(704, 1279, 3) type<class 'numpy.ndarray'>:

# %%
f, axarr = plt.subplots(1,2)
axarr[0].imshow(cv2.cvtColor(guy_image, cv2.COLOR_BGR2RGB))
axarr[1].imshow(cv2.cvtColor(road_image, cv2.COLOR_BGR2RGB))

# %%
def cartoonify(img):
  gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  smooth_image = cv2.medianBlur(gray_image,7)
  edge_image = cv2.Laplacian(smooth_image,-1,ksize=5)
  _, thresh1 = cv2.threshold(edge_image, 120, 255, cv2.THRESH_BINARY_INV)
  bilateral = cv2.bilateralFilter(img, d= 9, sigmaColor= 75, sigmaSpace= 42)
  bilateral[thresh1==0] = 0
  return bilateral

# %%
cv2_imshow(cartoonify(guy_image ))
# Out:
# <PIL.Image.Image image mode=RGB size=263x397 at 0x7F591086C090>

# %%
bottle_image = cv2.imread("bottle.jfif")

# %%
cv2_imshow(bottle_image)
# Out:
# <PIL.Image.Image image mode=RGB size=218x231 at 0x7F9BD0771A10>

# %%
cv2_imshow(cartoonify(bottle_image))
# Out:
# <PIL.Image.Image image mode=RGB size=218x231 at 0x7F9BD076D190>

# %%
nb_image = cv2.imread("notebook.jpg")
cv2_imshow(nb_image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x750 at 0x7F9BD0787710>

# %%
cv2_imshow(cartoonify(nb_image))
# Out:
# <PIL.Image.Image image mode=RGB size=500x750 at 0x7F9BD077F190>

# %%
model_image = cv2.imread("model.jpg")
cv2_imshow(model_image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x334 at 0x7F9BD077F550>

# %%
cv2_imshow(cartoonify(model_image))
# Out:
# <PIL.Image.Image image mode=RGB size=500x334 at 0x7F9BD077FE10>
